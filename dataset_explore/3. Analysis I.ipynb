# %%
# %pip install pynapple

# %%
import numpy as np
import matplotlib.pyplot as plt
import pynapple as nap

# %%
data = nap.load_file('sub-P11HMH_ses-20061101_ecephys+image.nwb')

# %%
spikes = data['units']
trials = data['trials']
# Out:
# c:\Users\sangeetha\anaconda3\envs\dexplore\Lib\site-packages\pynapple\io\interface_nwb.py:465: UserWarning: Too many metadata. Returning pandas.DataFrame, not IntervalSet
#   data = self._f_eval[self.data[key]["type"]](

# %%
trials
# Out:
#       start_time    stop_time  stim_on_time  stim_off_time  delay1_time  \
# id
# 0    6821.208244  6826.937364   6821.208244    6822.210644  6822.711364
# 1    6827.084244  6830.582604   6827.084244    6828.079084  6828.579804
# 2    6830.675884  6833.647084   6830.675884    6831.674324  6832.175044
# 3    6833.779164  6837.162204   6833.779164    6834.778844  6835.279524
# 4    6837.301244  6840.487044   6837.301244    6838.304044  6838.804724
# ..           ...          ...           ...            ...          ...
# 195  9077.267863  9080.428903   9077.267863    9078.265943  9078.766623
# 196  9080.475063  9083.243023   9080.475063    9081.470543  9081.971263
# 197  9083.314023  9086.627943   9083.314023    9084.314823  9084.815543
# 198  9086.688863  9089.542183   9086.688863    9087.689703  9088.190343
# 199  9089.634663  9093.127543   9089.634663    9090.633903  9091.134623
#
#      delay2_time stim_phase  stimCategory category_name  \
# id
# ...

# %% [markdown]
# https://www.nature.com/articles/s41597-020-0415-9/tables/2

# %%
trials['response_value'].value_counts()
# Out:
# response_value
# 1.0     80
# 32.0    27
# 0.0     20
# 34.0    16
# 33.0    16
# 35.0    16
# 36.0    15
# 31.0    10
# Name: count, dtype: int64
